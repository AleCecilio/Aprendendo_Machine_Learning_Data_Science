# %% [markdown]
# ## Continuando os Estudos de Suport Vector Machive (SVM) ou Máquina de Vetores de Suporte, mas agora com foco em Regressão

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/cement_slump.csv')
